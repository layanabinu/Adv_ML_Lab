# %%
import pandas as pd
Data = pd.read_csv(r'C:\vscodefolder\AML_Lab\Datasets\UnivariateData.csv')
print(Data.head())
print(Data.describe())
# Out:
#           X         y
# 0  0.749080  6.334288
# 1  1.901429  9.405278
# 2  1.463988  8.483724
# 3  1.197317  5.604382
# 4  0.312037  4.716440
#                 X           y
# count  100.000000  100.000000
# mean     0.940361    6.820004
# std      0.594979    1.879138
# min      0.011044    3.238062
# 25%      0.386402    5.302794
# 50%      0.928285    6.676056
# 75%      1.460406    8.297638
# max      1.973774   11.044395

# %%
X = Data.loc[: , 'X']
y = Data.loc[: , 'y']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X = Data.loc[: , 'X']
#       2 y = Data.loc[: , 'y']
#
# NameError: name 'Data' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(X, y, 'o')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# %%
X = X.values
y = y.values
X.shape
# Out:
# (100,)

# %%
X = X.reshape(-1, 1)
X.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state = 1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80, 1)
# (20, 1)
# (80,)
# (20,)

# %%
plt.plot(X_train, y_train, 'go')
plt.xlabel('X_train')
plt.ylabel('y_train')
plt.title('80% training')
plt.show()
plt.plot(X_test, y_test, 'ro')
plt.xlabel('X_test')
plt.ylabel('y_test')
plt.title('20% testing')
# Out:
# Text(0.5, 1.0, '20% testing')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print("Intercept : ",model.intercept_)
# Out:
# Intercept :  4.304363361858154

# %%
print("Coefficient : ",model.coef_)
# Out:
# Coefficient :  [2.64215635]

# %%
y_pred
# Out:
# array([8.86527176, 5.94769119, 9.31857126, 7.59806557, 7.27032759,
#        7.07734044, 5.91403777, 6.052932  , 9.51938254, 7.17213917,
#        8.32458946, 6.63026678, 4.77198541, 9.26896955, 8.40040759,
#        4.64811632, 5.20546615, 5.67183771, 6.19860836, 4.41313827])

# %%
y_test
# Out:
# array([11.04439507,  4.89121226,  9.61886731,  8.21362168,  6.61392702,
#         6.82087644,  5.88791282,  4.79408465, 10.70314449,  8.56331925,
#         8.31932218,  6.9424623 ,  3.4686513 ,  9.73664501,  8.08449921,
#         4.64785995,  5.19772255,  6.34371184,  6.44386684,  5.03890908])

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 0.6439758731413683
# MSE is 0.7385204987522751
# R2 score is 0.8316349196572903
